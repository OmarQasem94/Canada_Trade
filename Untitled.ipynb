# %%
# Importing dependencied
import pandas as pd
import numpy as np

# %%
# Creating pandas dataframe
Can_Trade = pd.read_csv('12100119.csv', index_col=False)

# Viewing dataframe
Can_Trade
# Out:
# C:\Users\omarr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         REF_DATE      GEO           DGUID            Trade  \
# 0        1997-01   Canada  2016A000011124           Import
# 1        1997-01   Canada  2016A000011124           Import
# 2        1997-01   Canada  2016A000011124           Import
# 3        1997-01   Canada  2016A000011124           Import
# 4        1997-01   Canada  2016A000011124           Import
# ...          ...      ...             ...              ...
# 3336068  2022-07  Nunavut     2016A000262  Domestic export
# 3336069  2022-07  Nunavut     2016A000262  Domestic export
# 3336070  2022-07  Nunavut     2016A000262  Domestic export
# 3336071  2022-07  Nunavut     2016A000262  Domestic export
# 3336072  2022-07  Nunavut     2016A000262  Domestic export
#
# ...

# %%
# Cleaning the dataframe

# Removing unimportant columns
Canada_Trade_df = Can_Trade.drop(columns=['DGUID', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS', 'COORDINATE'])

# Removing specific rows that will lead to double counting
Canada_Trade_df = Canada_Trade_df.drop(Canada_Trade_df[(Canada_Trade_df['GEO']=='Canada') & (Canada_Trade_df['Trade']!='Re-export')].index)
Canada_Trade_df = Canada_Trade_df.drop(Canada_Trade_df[(Canada_Trade_df['Principal trading partners']=='All countries')].index)
Canada_Trade_df = Canada_Trade_df.drop(Canada_Trade_df[(Canada_Trade_df['North American Product Classification System (NAPCS)']=='Total of all merchandise')].index)

# Multiplying the VALUE column by 1000 to correct the values to the exact dollar amount
Canada_Trade_df['VALUE'] = Canada_Trade_df['VALUE']*1000

# Inserting commas to the VALUE column and converting it back to 
Canada_Trade_df['VALUE'] = Canada_Trade_df.apply(lambda x: "{:,}".format(x['VALUE']), axis=1)
Canada_Trade_df

# %%
Canada_Trade_df.dtypes
# Out:
# REF_DATE                                                object
# GEO                                                     object
# Trade                                                   object
# North American Product Classification System (NAPCS)    object
# Principal trading partners                              object
# VALUE                                                   object
# dtype: object

# %%
Canada_Trade_df.keys()
# Out:
# Index(['REF_DATE', 'GEO', 'Trade',
#        'North American Product Classification System (NAPCS)',
#        'Principal trading partners', 'VALUE'],
#       dtype='object')

# %%
Canada_Trade_df.to_csv('Canada_Trade_Data.csv', index=False)
